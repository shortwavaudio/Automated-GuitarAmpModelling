# %%
# !git clone https://github.com/shortwavaudio/Automated-GuitarAmpModelling.git
# Out:
# Cloning into 'Automated-GuitarAmpModelling'...
# remote: Enumerating objects: 263, done.
# remote: Counting objects: 100% (231/231), done.
# remote: Compressing objects: 100% (177/177), done.
# remote: Total 263 (delta 70), reused 174 (delta 28), pack-reused 32
# Receiving objects: 100% (263/263), 126.24 MiB | 26.39 MiB/s, done.
# Resolving deltas: 100% (73/73), done.
# Checking out files: 100% (44/44), done.

# %%
cd Automated-GuitarAmpModelling/
# Out:
# /content/Automated-GuitarAmpModelling

# %%
# !git submodule update --init --recursive
# Out:
# Submodule 'CoreAudioML' (https://github.com/shortwavaudio/CoreAudioML) registered for path 'CoreAudioML'
# Cloning into '/content/Automated-GuitarAmpModelling/CoreAudioML'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/shortwavaudio/CoreAudioML
#  * branch            0831965db63add6498c1849f757a95e6c3c81f33 -> FETCH_HEAD
# Submodule path 'CoreAudioML': checked out '0831965db63add6498c1849f757a95e6c3c81f33'

# %%
# Upload your input.wav and output.wav, and add your config to the config directory.

# Name the .wav files and config file appropriately in the following command
# !python prep_wav.py /content/crunch-di-v2-1.wav /content/crunch-amp-v2-1.wav g20-profiles-crunch

# %%
# Name your config in the following command
# The model will be located in Results/
# !python dist_model_recnet.py -l "revv" --learn_rate 0.00015625
# --epochs 200 --validation_f 1 --validation_p 20
# Out:
# existing model file found, loading network
# cuda device not available/not selected
# unimplemented audio data type conversion...
# unimplemented audio data type conversion...
# unimplemented audio data type conversion...
# unimplemented audio data type conversion...
# unimplemented audio data type conversion...
# unimplemented audio data type conversion...
# Epoch:  1
# current learning rate: 0.00015625
# Epoch:  2
# Val loss: tensor(0.0165)
# current learning rate: 0.00015625
# Epoch:  3
# current learning rate: 0.00015625
# Epoch:  4
# Val loss: tensor(inf)
# current learning rate: 0.00015625
# Epoch:  5
# current learning rate: 0.00015625
# Epoch:  6
# Val loss: tensor(0.0170)
# current learning rate: 0.00015625
# Epoch:  7
# current learning rate: 0.00015625
# Epoch:  8
# Val loss: tensor(0.0162)
# current learning rate: 0.00015625
# Epoch:  9
# current learning rate: 0.00015625
# Epoch:  10
# Val loss: tensor(0.0184)
# current learning rate: 0.00015625
# Epoch:  11
# ...
